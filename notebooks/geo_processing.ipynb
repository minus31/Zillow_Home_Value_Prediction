# %%
from selenium import webdriver
import selenium 

driver = webdriver.Chrome()

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("https://www.latlong.net/Show-Latitude-Longitude.html")
soup = BeautifulSoup(res.content, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
driver.get("https://www.latlong.net/Show-Latitude-Longitude.html")
# Out:
# <selenium.webdriver.phantomjs.webdriver.WebDriver (session="b3f15a70-7d1e-11e8-b70a-9b599de6a47f")>

# %%
driver.get("https://www.latlong.net/Show-Latitude-Longitude.html")
driver.find_element_by_xpath(r'//*[@id="iC5705"]')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-26-811c7b06ceb2> in <module>()
#       1 driver.get("https://www.latlong.net/Show-Latitude-Longitude.html")
# ----> 2 driver.find_element_by_xpath(r'//*[@id="iC5705"]')
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/python_ana/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     385             element = driver.find_element_by_xpath('//div/td[1]')
#     386         """
# --> 387         return self.find_element(by=By.XPATH, value=xpath)
#     388
#     389     def find_elements_by_xpath(self, xpath):
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/python_ana/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     955         return self.execute(Command.FIND_ELEMENT, {
#     956             'using': by,
# ...

# %%
dir(driver)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_web_element_cls',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_script',
#  'file_detector',
#  'file_detector_context',
#  'find_element',
#  'find_element_by_class_name',
# ...
